# %%
import pandas as pd

# %%
df = pd.read_csv("companies_rw.csv")

df
# Out:
#                        Company Name             Type Category Criteria  \
# 0    Dishman Carbogen Amcis Limited              Job        A        -
# 1         Tata Consultancy Services              Job        A        6
# 2       Optimized Solutions Limited  Internship, Job        A        6
# 3                            Unisys       Internship        A        -
# 4         Grant Thornton Bharat LLP              Job       A1        -
# ..                              ...              ...      ...      ...
# 139                         SAS R&D  Job, Internship       A1        7
# 140                         Siemens              Job        A        -
# 141                 HDFC Bank India              Job        A        5
# 142          Cadence Design Systems              Job        A        7
# 143                           Flits              Job       A1        6
#
#           Placement Date                             Open For
# ...

# %%
# indexes

df.index
# Out:
# RangeIndex(start=0, stop=144, step=1)

# %%
# Columns

df.columns
# Out:
# Index(['Company Name', 'Type', 'Category', 'Criteria', 'Placement Date',
#        'Open For'],
#       dtype='object')

# %%
# describe

df.describe()
# Out:
#         Company Name             Type Category Criteria       Placement Date  \
# count            144              144      144      144                  144
# unique           141                7        2        9                   56
# top     MAQ Software  Job, Internship        A        -  2022-00-00 00:00:00
# freq               2               58       72       52                   75
#
#                                    Open For
# count                                   144
# unique                                   25
# top     BTech, MTech, MscIT, MscDS, MTechEC
# freq                                     35

# %%
# show pecidic data

df.head(4)
# Out:
#                      Company Name             Type Category Criteria  \
# 0  Dishman Carbogen Amcis Limited              Job        A        -
# 1       Tata Consultancy Services              Job        A        6
# 2     Optimized Solutions Limited  Internship, Job        A        6
# 3                          Unisys       Internship        A        -
#
#         Placement Date                             Open For
# 0   2023-11-30 0:00:00  BTech, MTech, MscIT, MscDS, MTechEC
# 1   2023-11-30 0:00:00  BTech, MTech, MscIT, MscDS, MTechEC
# 2  2023-00-00 00:00:00                  BTech, MTech, MscIT
# 3  2023-00-00 00:00:00                                MTech
