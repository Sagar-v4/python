# %%
import pandas as pd

# %%
com = pd.read_csv("companies.csv")

com
# Out:
#                        Company Name             Type Category Criteria  \
# 0    Dishman Carbogen Amcis Limited              Job        A        -
# 1         Tata Consultancy Services              Job        A        6
# 2       Optimized Solutions Limited  Internship, Job        A        6
# 3                            Unisys       Internship        A        -
# 4         Grant Thornton Bharat LLP              Job       A1        -
# ..                              ...              ...      ...      ...
# 139                         SAS R&D  Job, Internship       A1        7
# 140                         Siemens              Job        A        -
# 141                 HDFC Bank India              Job        A        5
# 142          Cadence Design Systems              Job        A        7
# 143                           Flits              Job       A1        6
#
#           Placement Date                             Open For
# ...

# %%
# Specific number of rows

com = pd.read_csv("companies.csv", nrows = 3)

com
# Out:
#                      Company Name             Type Category Criteria  \
# 0  Dishman Carbogen Amcis Limited              Job        A        -
# 1       Tata Consultancy Services              Job        A        6
# 2     Optimized Solutions Limited  Internship, Job        A        6
#
#         Placement Date                             Open For
# 0   2023-11-30 0:00:00  BTech, MTech, MscIT, MscDS, MTechEC
# 1   2023-11-30 0:00:00  BTech, MTech, MscIT, MscDS, MTechEC
# 2  2023-00-00 00:00:00                  BTech, MTech, MscIT

# %%
# Specific cols

com = pd.read_csv("companies.csv", nrows = 3, usecols = ["Company Name", "Open For"])

com
# Out:
#                      Company Name                             Open For
# 0  Dishman Carbogen Amcis Limited  BTech, MTech, MscIT, MscDS, MTechEC
# 1       Tata Consultancy Services  BTech, MTech, MscIT, MscDS, MTechEC
# 2     Optimized Solutions Limited                  BTech, MTech, MscIT

# %%
# Specific cols with their indexes

com = pd.read_csv("companies.csv", nrows = 3, usecols = [0, 5])

com
# Out:
#                      Company Name                             Open For
# 0  Dishman Carbogen Amcis Limited  BTech, MTech, MscIT, MscDS, MTechEC
# 1       Tata Consultancy Services  BTech, MTech, MscIT, MscDS, MTechEC
# 2     Optimized Solutions Limited                  BTech, MTech, MscIT

# %%
# Skip rows by row numbers

com = pd.read_csv("companies.csv", nrows = 3, usecols = [0, 5], skiprows = [0, 1])

com
# Out:
#      Tata Consultancy Services BTech, MTech, MscIT, MscDS, MTechEC
# 0  Optimized Solutions Limited                 BTech, MTech, MscIT
# 1                       Unisys                               MTech
# 2    Grant Thornton Bharat LLP               BTech, MTech, MTechEC

# %%
# Index call

com = pd.read_csv("companies.csv", nrows = 3, index_col = "Company Name")

com
# Out:
#                                            Type Category Criteria  \
# Company Name
# Dishman Carbogen Amcis Limited              Job        A        -
# Tata Consultancy Services                   Job        A        6
# Optimized Solutions Limited     Internship, Job        A        6
#
#                                      Placement Date  \
# Company Name
# Dishman Carbogen Amcis Limited   2023-11-30 0:00:00
# Tata Consultancy Services        2023-11-30 0:00:00
# Optimized Solutions Limited     2023-00-00 00:00:00
#
#                                                            Open For
# Company Name
# Dishman Carbogen Amcis Limited  BTech, MTech, MscIT, MscDS, MTechEC
# Tata Consultancy Services       BTech, MTech, MscIT, MscDS, MTechEC
# Optimized Solutions Limited                     BTech, MTech, MscIT

# %%
# Headers

com = pd.read_csv("companies.csv", nrows = 3, header = 2)

com
# Out:
#      Tata Consultancy Services              Job   A  6   2023-11-30 0:00:00  \
# 0  Optimized Solutions Limited  Internship, Job   A  6  2023-00-00 00:00:00
# 1                       Unisys       Internship   A  -  2023-00-00 00:00:00
# 2    Grant Thornton Bharat LLP              Job  A1  -  2023-00-00 00:00:00
#
#   BTech, MTech, MscIT, MscDS, MTechEC
# 0                 BTech, MTech, MscIT
# 1                               MTech
# 2               BTech, MTech, MTechEC

# %%
# Headers

com = pd.read_csv("companies.csv", nrows = 3, names = ["A", "B", "C", "D", "E", "F"])

com
# Out:
#                                 A     B         C         D  \
# 0                    Company Name  Type  Category  Criteria
# 1  Dishman Carbogen Amcis Limited   Job         A         -
# 2       Tata Consultancy Services   Job         A         6
#
#                     E                                    F
# 0      Placement Date                             Open For
# 1  2023-11-30 0:00:00  BTech, MTech, MscIT, MscDS, MTechEC
# 2  2023-11-30 0:00:00  BTech, MTech, MscIT, MscDS, MTechEC

# %%
# Headers

com = pd.read_csv("companies.csv", nrows = 3, header = None)

com
# Out:
#                                 0     1         2         3  \
# 0                    Company Name  Type  Category  Criteria
# 1  Dishman Carbogen Amcis Limited   Job         A         -
# 2       Tata Consultancy Services   Job         A         6
#
#                     4                                    5
# 0      Placement Date                             Open For
# 1  2023-11-30 0:00:00  BTech, MTech, MscIT, MscDS, MTechEC
# 2  2023-11-30 0:00:00  BTech, MTech, MscIT, MscDS, MTechEC

# %%
# Change column data type

types = {
    "Criteria": "float"
}
com = pd.read_csv("companies.csv", nrows = 2, skiprows = [1], dtype = types)

com
# Out:
#                   Company Name             Type Category  Criteria  \
# 0    Tata Consultancy Services              Job        A       6.0
# 1  Optimized Solutions Limited  Internship, Job        A       6.0
#
#         Placement Date                             Open For
# 0   2023-11-30 0:00:00  BTech, MTech, MscIT, MscDS, MTechEC
# 1  2023-00-00 00:00:00                  BTech, MTech, MscIT
